# %%
from jupyterpatgen import *
from IPython.display import display, Markdown, Latex

# %%
PARAM_TO_USE = "cs-sojka-sizeoptimized" # can use german8levels-orig, sojka-sizeoptimized, liang, etc.

# %%
statsfreq = train(".", PARAM_TO_USE, output_markdown=True)

# %%
display(Markdown(stats))
# Out:
# ## cs-sojka-sizeoptimized
#
# Took: 40.48 seconds
#
# Level|Patterns|Good|Bad|Missed|Length|Param
# ---|---|---|---|---|---|---
# 1 | 327 | 2257311 | 538667 | 12727 | 1 3 | 1 2 20
# 2 | 1176 | 1920317 | 1058 | 349721 | 2 4 | 2 1 8
# 3 | 2079 | 2263373 | 8554 | 6665 | 3 5 | 1 4 7
# 4 | 1579 | 2262328 | 0 | 7710 | 4 6 | 3 2 1

# %%
display(Markdown(statsfreq))
# Out:
# ## cs-sojka-sizeoptimized
#
# Took: 31.46 seconds
#
# Level|Patterns|Good|Bad|Missed|Length|Param
# ---|---|---|---|---|---|---
# 1 | 357 | 4996630 | 1132118 | 25089 | 1 3 | 1 2 20
# 2 | 1375 | 4376063 | 1033 | 645656 | 2 4 | 2 1 8
# 3 | 2566 | 5014438 | 17345 | 7281 | 3 5 | 1 4 7
# 4 | 1619 | 5011865 | 0 | 9854 | 4 6 | 3 2 1

# %%
#display(Markdown(validate(".", PARAM_TO_USE))) WITHOUT FREQUENCIES
# Out:
# ## Pattern cs-sojka-sizeoptimized
#
# 3352 patterns, 17 kB
#
# 260047 good, 18838 bad, 10137 missed
# 96.25 %, 6.97 %, 3.75 %

# %%
display(Markdown(validate(".", PARAM_TO_USE))) # with frequencies used in training
# Out:
# ## Pattern cs-sojka-sizeoptimized
#
# 4016 patterns, 20 kB
#
# 260212 good, 18924 bad, 9972 missed
# 96.31 %, 7.00 %, 3.69 %
